# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Calculus_1/blob/main/Project_Part4_Newton_Integrals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part 4 Tricks and Tips
#
# ## Dr Jacob's Calculus 1

# %%
from sympy import *
import numpy as np

x = Symbol('x')

# %% [markdown]
# Starting with a complicated function, can we find the roots?

# %%
f = x**8-x**7-3*x**4-x**2+x-1

# %%
plot(f,(x,-10,10))

# %% [markdown]
# I cannot see any roots yet, let's zoom in to -5 to 5.

# %%
plot(f,(x,-5,5))

# %% [markdown]
# Still no idea!  Zoom in more!

# %%
plot(f,(x,-2,2))

# %% [markdown]
# That's better!  Clearly I see one near -1.5 and 1.5.  Let's look and see if I can find others.  ZOOOOOMMM!

# %%
plot(f,0,(x,-1.5,1.5))

# %% [markdown]
# So I think there are 2 roots!  I had a possiblity of 8 so I think I have candidates for all possibilities.  I stuck the 0 in there to keep the graphic centered on 0.

# %% [markdown]
# To find them, I'll use `nsolve`  I need to give it a solution near my point!

# %%
nsolve(f,x,1.5)
# Out:
# 1.68409845773313

# %%
nsolve(f,x,-1.5)
# Out:
# -1.26035079148018

# %%
nsolve(f,x,1)
# Out:
# 1.68409845773313

# %% [markdown]
# Opps, already found that one.  Are there any others?  I don't think so!

# %%
nsolve(f,x,.8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-d0f7fb0c81eb> in <module>
# ----> 1 nsolve(f,x,.8)
#
# /usr/local/lib/python3.7/dist-packages/sympy/utilities/decorator.py in func_wrapper(*args, **kwargs)
#      86         dps = mpmath.mp.dps
#      87         try:
# ---> 88             return func(*args, **kwargs)
#      89         finally:
#      90             mpmath.mp.dps = dps
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solvers.py in nsolve(dict, *args, **kwargs)
#    2932
#    2933         f = lambdify(fargs, f, modules)
# -> 2934         x = sympify(findroot(f, x0, **kwargs))
#    2935         if as_dict:
#    2936             return [{fargs: x}]
#
# /usr/local/lib/python3.7/dist-packages/mpmath/calculus/optimization.py in findroot(ctx, f, x0, solver, tol, verbose, verify, **kwargs)
#     986                              '(%s > %s)\n'
#     987                              'Try another starting point or tweak arguments.'
# --> 988                              % (norm(f(*xl))**2, tol))
#     989         return x
#     990     finally:
#
# ValueError: Could not find root within given tolerance. (0.667814436355803173015 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.

# %% [markdown]
# I am going to make a little `for` loop and see if I can find others.

# %%
z = np.linspace(-2,2,100) #just looking between -2 and 2.

for i in z:
  try:
    print(nsolve(f,x,i)) #if this errors it will not display
  except:
    print("Did not find solution")
# Out:
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# -1.26035079148018
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# 1.68409845773313
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# -1.26035079148018
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# 1.68409845773313
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# -1.26035079148018
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# -1.26035079148018
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# 1.68409845773313
# Did not find solution
# -1.26035079148018
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# Did not find solution
# 1.68409845773313
# Did not find solution
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313
# 1.68409845773313

# %% [markdown]
# The code above just allows for lots of attempts.  We see though that it only finds those same two solutions...

# %% [markdown]
# I might have also explored where the roots were by using the intermediate value theorem.  Here I am looking for negative and positive numbers, then I know the root is in-between those.

# %%
f.subs(x,1.67)
# Out:
# -1.18165379982273

# %%
f.subs(x,1.69)
# Out:
# 0.529875431325095

# %% [markdown]
# So there must be a root in the interval $(1.67,1.69)$.
